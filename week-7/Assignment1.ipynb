# %%
import numpy as np
import pandas as pd
data=pd.read_csv('spotify_data clean.csv')
data
# Out:
#                     track_id                                       track_name  \
# 0     3EJS5LyekDim1Tf5rBFmZl                    Trippy Mane (ft. Project Pat)
# 1     1oQW6G2ZiwMuHqlPpP27DB                                             OMG!
# 2     7mdkjzoIYlf1rx9EtBpGmU                                      Hard 2 Find
# 3     67rW0Zl7oB3qEpD5YWWE5w  Still Get Like That (ft. Project Pat & Starrah)
# 4     15xptTfRBrjsppW0INUZjf                            ride me like a harley
# ...                      ...                                              ...
# 8577  0AQquaENerGps8BQmbPw14                                         Big Iron
# 8578  4f8hBeMXMvssn6HtFAtblo                                          El Paso
# 8579  0Vy7wsXNFrbNc6UTWoScnM                                 Over the Rainbow
# 8580  760clbeDBWmBsBLbszWuNZ                                        I'm A Man
# 8581  61GEP8lryEfcuEgBMbRmNi                               Alone And Forsaken
#
# ...

# %%
data.isnull().sum()
# Out:
# track_id                 0
# track_name               0
# track_number             0
# track_popularity         0
# explicit                 0
# artist_name              3
# artist_popularity        0
# artist_followers         0
# artist_genres         3361
# album_id                 0
# album_name               0
# album_release_date       0
# album_total_tracks       0
# album_type               0
# track_duration_min       0
# dtype: int64

# %%
data['artist_genres'].fillna(data['artist_genres'].mode()[0],inplace=True)

# %%
data.isnull().sum()
# Out:
# track_id              0
# track_name            0
# track_number          0
# track_popularity      0
# explicit              0
# artist_name           0
# artist_popularity     0
# artist_followers      0
# artist_genres         0
# album_id              0
# album_name            0
# album_release_date    0
# album_total_tracks    0
# album_type            0
# track_duration_min    0
# dtype: int64

# %%
data['artist_name'].fillna(data['artist_name'].mode()[0],inplace=True)

# %%
import seaborn as sns
data['track_number'].skew()
data['track_number'].kurtosis()
sns.histplot(data['track_number'])
# Out:
# <Axes: xlabel='track_number', ylabel='Count'>

# %%
from sklearn.preprocessing import PowerTransformer
trans=PowerTransformer(method='box-cox')
trans1=PowerTransformer(method='yeo-johnson')
la_trans=trans.fit_transform(data[['track_number']])
la_trans.shape
# Out:
# (8582, 1)

# %%
print("Skewness:",pd.Series(la_trans.reshape(8582,)).skew())
print("Kurtosis:",pd.Series(la_trans.reshape(8582,)).kurtosis())
sns.histplot(la_trans)
# Out:
# Skewness: 0.03756364451863231
# Kurtosis: -1.3671891893066699
# <Axes: ylabel='Count'>

# %%
la_tracnum=trans.trans1.fit_transform(data[['track_number']])
sns.shape
# sns.histplot(la_tracnum)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 la_tracnum=trans.trans1.fit_transform(data[['track_number']])
#       2 sns.shape
#       3 sns.histplot(la_tracnum)
#
# NameError: name 'trans' is not defined
